# %%
import gspread
import pandas as pd
import matplotlib.pyplot as plt
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']

# %%
def createcredentials(stringname, sheetname):
    credentials = ServiceAccountCredentials.from_json_keyfile_name(stringname, scope)
    gc = gspread.authorize(credentials)
    wks = gc.open(sheetname).sheet1
    d = wks.get_all_records()
    print(type(d))
    df = pd.DataFrame(d)
    print(df)
    return df

# %%
df = createcredentials('/home/nidhi/Programming Files/Python Projects/newapilibrary-367ec85bcf11.json', 'testapisheet')
df.columns
# Out:
# <class 'list'>
#       city  rank  score1 score2
# 0  tripoli     1      44     67
# 1   sydney     2      48     63
# 2     rome     2      41     70
# 3     rome     2      79
# Index(['city', 'rank', 'score1', 'score2'], dtype='object')

# %%
plt.bar(df['city'], df['score1'])
plt.show()

# %%
plt.plot(df['city'], df['score1'])
plt.show()

# %%
plt.scatter(df['city'], df['score1'])
plt.show()

# %%
df
# Out:
#       city  rank  score1 score2
# 0  tripoli     1      44     67
# 1   sydney     2      48     63
# 2     rome     2      41     70
# 3     rome     2      79
